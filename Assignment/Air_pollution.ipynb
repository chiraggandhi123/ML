# %%
import numpy as np
import sklearn

# %%
import pandas as pd

# %%
df=pd.read_csv('/home/chirag/Desktop/chirag_ml/Assignment/Air_pollution/Training/Train.csv').values
dft=pd.read_csv('/home/chirag/Desktop/chirag_ml/Assignment/Air_pollution/Test/Test.csv').values

# %%
X=df[:,:-1]
Y=df[:,-1]

# %%
# Out:
# (400, 5)

# %%
from sklearn.linear_model import LinearRegression

# %%
Y=Y.reshape((-1,1))

# %%
lr=LinearRegression()

# %%
lr.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lr.intercept_
# Out:
# array([4.99096674])

# %%
lr.coef_
# Out:
# array([[29.68187118, 92.66247759,  8.28062089, 44.76773522,  2.51916121]])

# %%
Y=np.dot(X,lr.coef_.T)
Y
# Out:
# (1600, 1)

# %%
import matplotlib.pyplot as plt

# %%
for i in range(5):
    plt.scatter(X[:,i],Y)
plt.scatter(X[:,1],Y)

# %%
A=lr.predict(dft)
zero=np.zeros((A.shape[0],1))
for i in range(A.shape[0]):
    zero[i]=i

# %%
type(output)
# Out:
# numpy.ndarray

# %%
A=np.hstack((zero,A))

# %%
numpy.savetxt("foo.csv",A, delimiter=",")
