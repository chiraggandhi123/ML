# %%
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
J_B=cv2.imread('Traini/Jamie_Before.jpg')
J_A=cv2.imread('Traini/Jamie_After.jpg')

# %%
J_B=cv2.cvtColor(J_B,cv2.COLOR_BGR2RGBA)

# %%
plt.imshow(J_B)

# %%
J_A=cv2.cvtColor(J_A,cv2.COLOR_BGR2RGBA)

# %%
plt.imshow(J_A)

# %%
nose_cascade=cv2.CascadeClassifier('Traini/third-party/Nose18x15.xml')
eye_cascade = cv2.CascadeClassifier('Traini/third-party/frontalEyes35x16.xml')

# %%
noses=nose_cascade.detectMultiScale(J_B,1.3,5)
eyes=eye_cascade.detectMultiScale(J_B,1.3,5)

# %%
J_B=cv2.imread('Traini/Jamie_Before.jpg')
J_B=cv2.cvtColor(J_B,cv2.COLOR_BGR2RGBA)
x,y,w,h=eyes[0]
a,b,c,d=noses[0]
print(eyes[0])
eye_section=J_B[y:y+w,x:x+h]#first y then x
nose_section=J_B[b:b+c,a:a+d]
cv2.rectangle(J_B,((x,y)),((x+h,y+w)),(255,0,0,255),2)
cv2.rectangle(J_B,((a,b)),((a+d,b+c)),(255,0,0,255),2)
plt.imshow(J_B)
#plt.imshow(eye_section)
# Out:
# [192 334 170 371]

# %%
print(noses[0])
# Out:
# [311 485 110 132]

# %%
print(eyes)
# Out:
# [[192 334 170 371]]

# %%
#eye_section=eye_section.reshape((-1,1))

# %%
plt.imshow(eye_section)

# %%
plt.imshow(nose_section)

# %%
print(eyes)
print(eye_section)
# Out:
# [[192 334 170 371]]
# [[[255   0   0 255]
#   [255   0   0 255]
#   [255   0   0 255]
#   ...
#   [255   0   0 255]
#   [255   0   0 255]
#   [255   0   0 255]]
#
#  [[255   0   0 255]
#   [255   0   0 255]
#   [255   0   0 255]
#   ...
#   [255   0   0 255]
#   [255   0   0 255]
#   [255   0   0 255]]
#
#  [[255   0   0 255]
#   [255   0   0 255]
#   [ 56  30  17 255]
#   ...
#   [ 48  18   7 255]
#   [ 45  16   2 255]
#   [255   0   0 255]]
#
#  ...
#
#  [[255   0   0 255]
#   [255   0   0 255]
#   [161 113  90 255]
#   ...
#   [202 149 105 255]
#   [216 161 107 255]
#   [255   0   0 255]]
#
#  [[255   0   0 255]
#   [255   0   0 255]
#   [160 112  89 255]
#   ...
#   [203 151 104 255]
#   [218 163 107 255]
#   [255   0   0 255]]
#
#  [[255   0   0 255]
#   [255   0   0 255]
#   [255   0   0 255]
#   ...
#   [255   0   0 255]
#   [255   0   0 255]
#   [255   0   0 255]]]

# %%
glasses=cv2.imread('Traini/glasses.png',cv2.IMREAD_UNCHANGED)
moustache=cv2.imread('Traini/mustache.png',cv2.IMREAD_UNCHANGED)#cv2.cvtColor(glasses,cv2.COLOR_BGR2RGB)
#moustache=cv2.cvtColor(moustache,cv2.COLOR_RGBA2GRAY)
plt.imshow(moustache)

# %%
glasses=cv2.cvtColor(glasses,cv2.COLOR_BGRA2GRAY)

# %%
plt.imshow(glasses)

# %%
eye_section.shape
# Out:
# (170, 371, 4)

# %%
new_glasses=glasses[:170,:371]

# %%
plt.imshow(new)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-200-5bea267c7ecf> in <module>()
# ----> 1 plt.imshow(new)
#
# NameError: name 'new' is not defined

# %%
cv2.addWeighted(eye_section,0, new_glasses,1, 100,new)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-202-a97b5cf7e7b5> in <module>()
# ----> 1 cv2.addWeighted(eye_section,0, new_glasses,1, 100,new)
#
# NameError: name 'new' is not defined

# %%
print(eye_section.shape,glasses.shape)
# Out:
# (170, 371, 4) (221, 483, 4)

# %%
(wH,wW)=moustache.shape[:2]

# %%
(B, G, R, A) = cv2.split(moustache)
B = cv2.bitwise_and(B, B, mask=A)
G = cv2.bitwise_and(G, G, mask=A)
R = cv2.bitwise_and(R, R, mask=A)
moustache = cv2.merge([B, G, R, A])

# %%
moustache.shape
# Out:
# (320, 640, 4)

# %%
image=J_B

# %%
#image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
image.shape
# Out:
# (1024, 733, 4)

# %%
plt.imshow(image)

# %%
image=J_B
(h, w) = image.shape[:2]
image = np.dstack([image, np.ones((h, w), dtype="uint8") * 255])
print(image.shape)
 
	# construct an overlay that is the same size as the input
	# image, (using an extra dimension for the alpha transparency),
	# then add the watermark to the overlay in the bottom-right
	# corner
overlay = np.zeros((h, w,4), dtype="uint8")
overlay[h - wH - 400:h - 400, w - wW:w] = moustache
 
	# blend the two images together using transparent overlays
output = image.copy()
output=cv2.addWeighted(overlay,-244, output,1, 0,output)
# Out:
# (1024, 733, 5)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-110-42d9a753bf37> in <module>()
#      13         # blend the two images together using transparent overlays
#      14 output = image.copy()
# ---> 15 output=cv2.addWeighted(overlay,-244, output,1, 0,output)
#
# error: OpenCV(4.1.0) /io/opencv/modules/core/src/arithm.cpp:663: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'arithm_op'

# %%
overlay.shape
# Out:
# (1024, 733, 4)

# %%
plt.imshow(output)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-09aac1dc360d> in <module>()
# ----> 1 plt.imshow(output)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3099                         filternorm=filternorm, filterrad=filterrad,
#    3100                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3101                         **kwargs)
#    3102     finally:
#    3103         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# ...

# %%
plt.imshow(overlay)

# %%
zero=zero[320,640]+moustache
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-1f2c28fabf64> in <module>()
# ----> 1 zero=zero[320,640]+moustache
#
# NameError: name 'zero' is not defined

# %%
J_new=J_B[320,640]+moustache

# %%
J_B
# Out:
# array([[[178, 142, 120, 255],
#         [178, 142, 120, 255],
#         [179, 143, 121, 255],
#         ...,
#         [202, 148,  84, 255],
#         [201, 147,  83, 255],
#         [201, 147,  83, 255]],
#
#        [[176, 138, 117, 255],
#         [175, 139, 117, 255],
#         [176, 138, 117, 255],
#         ...,
#         [204, 150,  86, 255],
#         [203, 149,  85, 255],
#         [203, 149,  85, 255]],
#
#        [[173, 132, 110, 255],
#         [171, 133, 110, 255],
#         [174, 133, 111, 255],
#         ...,
#         [206, 153,  87, 255],
#         [206, 153,  87, 255],
#         [205, 152,  86, 255]],
#
#        ...,
#
#        [[ 34,  35,  40, 255],
#         [ 34,  35,  40, 255],
#         [ 34,  35,  40, 255],
#         ...,
#         [ 46,  45,  51, 255],
#         [ 42,  41,  47, 255],
#         [ 38,  37,  43, 255]],
#
#        [[ 34,  35,  40, 255],
#         [ 34,  35,  40, 255],
#         [ 35,  36,  41, 255],
#         ...,
#         [ 45,  44,  50, 255],
# ...
